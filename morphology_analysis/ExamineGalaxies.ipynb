# %%
import astropy
import astropy.io.ascii as ascii
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import astropy.io.fits as pyfits
import masshistory

sfid=99982   #Ring!
sfid=103701 #late merger
sfid=99450  #double nucleus
sfid=102672 #appears isolated
sfid=105747 #wreck
sfid=102098 #multi merger

sfid=99450  #double nucleus

masshistory.masshistory('snapshot_068',sfid,camnum=0,size=8,alph=1,Q=4,sb='SB27',gyrbox=False)
# Out:
# /Users/gsnyder/anaconda3/envs/astroconda/lib/python3.5/site-packages/h5py/_hl/selections.py:476: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   start, stop, step = exp.indices(length)
# 3.81838 3.51688 2.59221
# 0
